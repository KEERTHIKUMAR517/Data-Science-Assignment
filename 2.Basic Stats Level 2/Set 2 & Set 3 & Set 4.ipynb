# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Q1.

# %%
1-stats.norm.cdf(x = 60,loc =55,scale = 8 )
# Out:
# 0.26598552904870054

# %% [markdown]
# ### Q2.

# %%
stats.norm.cdf(44,38,6)
# Out:
# 0.8413447460685429

# %%
1-stats.norm.cdf(44,38,6)
# Out:
# 0.15865525393145707

# %%
stats.norm.cdf(44,38,6) - stats.norm.cdf(38,38,6)
# Out:
# 0.3413447460685429

# %%
stats.norm.cdf(30,38,6)
# Out:
# 0.09121121972586788

# %% [markdown]
# ### Q3.

# %%
np.random.seed(123)
n1 = np.random.randn(100,)
n1
# Out:
# array([-1.0856306 ,  0.99734545,  0.2829785 , -1.50629471, -0.57860025,
#         1.65143654, -2.42667924, -0.42891263,  1.26593626, -0.8667404 ,
#        -0.67888615, -0.09470897,  1.49138963, -0.638902  , -0.44398196,
#        -0.43435128,  2.20593008,  2.18678609,  1.0040539 ,  0.3861864 ,
#         0.73736858,  1.49073203, -0.93583387,  1.17582904, -1.25388067,
#        -0.6377515 ,  0.9071052 , -1.4286807 , -0.14006872, -0.8617549 ,
#        -0.25561937, -2.79858911, -1.7715331 , -0.69987723,  0.92746243,
#        -0.17363568,  0.00284592,  0.68822271, -0.87953634,  0.28362732,
#        -0.80536652, -1.72766949, -0.39089979,  0.57380586,  0.33858905,
#        -0.01183049,  2.39236527,  0.41291216,  0.97873601,  2.23814334,
#        -1.29408532, -1.03878821,  1.74371223, -0.79806274,  0.02968323,
#         1.06931597,  0.89070639,  1.75488618,  1.49564414,  1.06939267,
#        -0.77270871,  0.79486267,  0.31427199, -1.32626546,  1.41729905,
# ...

# %%
np.random.seed(123)
n2 = np.random.randn(100)
n2
# Out:
# array([-1.0856306 ,  0.99734545,  0.2829785 , -1.50629471, -0.57860025,
#         1.65143654, -2.42667924, -0.42891263,  1.26593626, -0.8667404 ,
#        -0.67888615, -0.09470897,  1.49138963, -0.638902  , -0.44398196,
#        -0.43435128,  2.20593008,  2.18678609,  1.0040539 ,  0.3861864 ,
#         0.73736858,  1.49073203, -0.93583387,  1.17582904, -1.25388067,
#        -0.6377515 ,  0.9071052 , -1.4286807 , -0.14006872, -0.8617549 ,
#        -0.25561937, -2.79858911, -1.7715331 , -0.69987723,  0.92746243,
#        -0.17363568,  0.00284592,  0.68822271, -0.87953634,  0.28362732,
#        -0.80536652, -1.72766949, -0.39089979,  0.57380586,  0.33858905,
#        -0.01183049,  2.39236527,  0.41291216,  0.97873601,  2.23814334,
#        -1.29408532, -1.03878821,  1.74371223, -0.79806274,  0.02968323,
#         1.06931597,  0.89070639,  1.75488618,  1.49564414,  1.06939267,
#        -0.77270871,  0.79486267,  0.31427199, -1.32626546,  1.41729905,
# ...

# %%
plt.figure(figsize= (8,6))
plt.subplot(2,2,1)
plt.hist(n1)
plt.subplot(2,2,2)
plt.hist(n2)
plt.show()

# %%
from scipy import stats
stats.probplot(n1,plot = plt)
plt.show()

# %%
from scipy import stats
stats.probplot(n2,plot = plt)
plt.show()

# %%
n3 = n1*2
n3
# Out:
# array([-2.17126121,  1.99469089,  0.565957  , -3.01258943, -1.1572005 ,
#         3.30287307, -4.85335849, -0.85782526,  2.53187252, -1.7334808 ,
#        -1.3577723 , -0.18941794,  2.98277925, -1.27780399, -0.88796392,
#        -0.86870255,  4.41186017,  4.37357218,  2.0081078 ,  0.7723728 ,
#         1.47473715,  2.98146406, -1.87166774,  2.35165809, -2.50776134,
#        -1.275503  ,  1.81421039, -2.8573614 , -0.28013744, -1.72350979,
#        -0.51123874, -5.59717821, -3.54306621, -1.39975447,  1.85492486,
#        -0.34727137,  0.00569183,  1.37644542, -1.75907269,  0.56725465,
#        -1.61073304, -3.45533899, -0.78179959,  1.14761172,  0.6771781 ,
#        -0.02366099,  4.78473053,  0.82582432,  1.95747201,  4.47628668,
#        -2.58817065, -2.07757642,  3.48742445, -1.59612547,  0.05936646,
#         2.13863194,  1.78141278,  3.50977236,  2.99128827,  2.13878534,
#        -1.54541743,  1.58972534,  0.62854399, -2.65253092,  2.83459809,
# ...

# %%
n4 = n1+n2
n4
# Out:
# array([-2.17126121,  1.99469089,  0.565957  , -3.01258943, -1.1572005 ,
#         3.30287307, -4.85335849, -0.85782526,  2.53187252, -1.7334808 ,
#        -1.3577723 , -0.18941794,  2.98277925, -1.27780399, -0.88796392,
#        -0.86870255,  4.41186017,  4.37357218,  2.0081078 ,  0.7723728 ,
#         1.47473715,  2.98146406, -1.87166774,  2.35165809, -2.50776134,
#        -1.275503  ,  1.81421039, -2.8573614 , -0.28013744, -1.72350979,
#        -0.51123874, -5.59717821, -3.54306621, -1.39975447,  1.85492486,
#        -0.34727137,  0.00569183,  1.37644542, -1.75907269,  0.56725465,
#        -1.61073304, -3.45533899, -0.78179959,  1.14761172,  0.6771781 ,
#        -0.02366099,  4.78473053,  0.82582432,  1.95747201,  4.47628668,
#        -2.58817065, -2.07757642,  3.48742445, -1.59612547,  0.05936646,
#         2.13863194,  1.78141278,  3.50977236,  2.99128827,  2.13878534,
#        -1.54541743,  1.58972534,  0.62854399, -2.65253092,  2.83459809,
# ...

# %%
stats.probplot(n3,plot = plt)
plt.show()

# %%
stats.probplot(n4,plot = plt)
plt.show()

# %% [markdown]
# # Q4.

# %%
stats.norm.ppf(0.005)
# Out:
# -2.575829303548901

# %%
stats.norm.ppf(0.995)
# Out:
# 2.5758293035489004

# %% [markdown]
# # Q5.

# %%
# mean of two different companies
Mean = 5+7
Mean
# Out:
# 12

# %%
# 1$  = 45Rs.
print('Mean Profit is Rs', Mean*45,'Million')
# Out:
# Mean Profit is Rs 540 Million

# %%
SD = np.sqrt((9)+(16))
print('Standard Deviation is Rs', SD*45, 'Million')
# Out:
# Standard Deviation is Rs 225.0 Million

# %%
#A
print('Range is Rs',(stats.norm.interval(0.95,540,225)),'in Millions')
# Out:
# Range is Rs (99.00810347848784, 980.9918965215122) in Millions

# %%
# To compute 5th Percentile, we use the formula X=μ + Zσ; wherein from z table, 5 percentile = -1.645
X= 540+(-1.645)*(225)
print('5th percentile of profit (in Million Rupees) is',np.round(X,))
# Out:
# 5th percentile of profit (in Million Rupees) is 170.0

# %%
# Probability of Division 1 making a loss P(X<0)
stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
# Probability of Division 2 making a loss P(X<0)
stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086

# %% [markdown]
# #### Probability of Division 1 making a loss in a given year is more than Division 2.

# %% [markdown]
# # Set 3

# %% [markdown]
# ##  Q5.

# %%
# This is One Sample Proportion Test
#H0: p >= 5%
# H1: p< 5%

# %%
np.sqrt(2.326/0.04)*
# Out:
# 7.625614729318548

# %% [markdown]
# # Set 4

# %% [markdown]
# ## Q3.

# %% [markdown]
# ####  n=100, Pop Mean=50, Pop SD=40 As no. of samples is more than 30, we can consider it normal distribution

# %%
# H0: No investigation P(45<X<55)
# H1: Investigation 1-P(45<X<55)

# %%
# find z-scores at x=45; z=(s_mean-P_mean)/(p_SD/sqrt(n))
t = (45 - 50)/ (40/np.sqrt(100))
t
# Out:
# -1.25

# %%
t = (45 - 50)/ (40/np.sqrt(100))

# %%
# find z-scores at x=55; z=(s_mean-P_mean)/(p_SD/sqrt(n))
t2=(55-50)/(40/np.sqrt(100))
t2
# Out:
# 1.25

# %%
# For No investigation P(45<X<55) using z_scores = P(X<50)-P(X<45)
stats.norm.cdf(1.25)-stats.norm.cdf(-1.25)
# Out:
# 0.7887004526662893

# %%
# For Investigation 1-P(45<X<55)
1-0.7887
# Out:
# 0.21130000000000004

# %%
stats.norm.interval(0.7887,loc=50,scale=40/(100**0.5))
# Out:
# (45.00000495667348, 54.99999504332652)

# %% [markdown]
# #### Answer is D. 21.1%
